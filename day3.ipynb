# %% [markdown]
# # How do I apply filter criteria to a Panda dataframe?

# %%
import pandas as pd

# %%
movies = pd.read_csv('imdb.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies[movies['duration'] >=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# Logical operators:
# AND OR
# AND - true only only if both sides of the operator are true (both the conditions should be true)
print(True and True)
# Out:
# True

# %%
# OR - True if either side of the operator is true(atleast one of the condition should be true)
print(False or False)
# Out:
# False

# %%
# 1. duration>=200
# 2. genre = drama
movies[(movies['duration']>=200) & (movies['genre'] =='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %% [markdown]
# # How do I handle missing values in Pandas

# %%
# Based on business objective and dataset, analysts decides whethere to drop the null values
# or to impute values in place of null values
# 1. How to drop null values

# %%
ufo = pd.read_csv('ufo.csv')
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
# 'isnull' returns a dataframe of boolean value( True if missing)
ufo.isnull()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# ...      ...              ...             ...    ...    ...
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False
#
# [18241 rows x 5 columns]

# %%
# 'notnull' returns a dataframe of boolean value( True if not missing)
ufo.notnull()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 0      True            False            True   True  True
# 1      True            False            True   True  True
# 2      True            False            True   True  True
# 3      True            False            True   True  True
# 4      True            False            True   True  True
# ...     ...              ...             ...    ...   ...
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True
#
# [18241 rows x 5 columns]

# %%
# Use the 'isnull' command to filter the dataframe
ufo[ufo['City'].isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
# Count the no.of missing values in each series
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported         0
# State                  0
# Time                   0
# dtype: int64

# %%
# Examine no.of rows:
ufo.shape
# Out:
# (18241, 5)

# %%
# if 'any' values are missing in a row, then drop that entire row
ufo.dropna(how = 'any').shape
# Out:
# (2486, 5)

# %%
# if 'all' values are missing in a row, then drop that entire row
ufo.dropna(how = 'all').shape
# Out:
# (18241, 5)

# %%
# if 'any' values are missing in a row( considering only city and shape reported) then drop  that entire row
ufo.dropna(subset = ['City', 'Shape Reported'],how = 'any').shape
# Out:
# (15576, 5)

# %%
# if 'all' values are missing in a row( considering only city and shape reported) then drop  that entire row
ufo.dropna(subset = ['City', 'Shape Reported'],how = 'all').shape
# Out:
# (18237, 5)

# %%
# 2. Imputing dummy values in place of null values

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# value_counts - gives the count of occurences of each unique value in a column
# By default, it does not include information related to missing values
ufo['Shape Reported'].value_counts(dropna = False)
# Out:
# LIGHT                 2803
# unidentified shape    2644
# DISK                  2122
# TRIANGLE              1889
# OTHER                 1402
# CIRCLE                1365
# SPHERE                1054
# FIREBALL              1039
# OVAL                   845
# CIGAR                  617
# FORMATION              434
# VARIOUS                333
# RECTANGLE              303
# CYLINDER               294
# CHEVRON                248
# DIAMOND                234
# EGG                    197
# FLASH                  188
# TEARDROP               119
# CONE                    60
# CROSS                   36
# DELTA                    7
# CRESCENT                 2
# ROUND                    2
# FLARE                    1
# HEXAGON                  1
# DOME                     1
# PYRAMID                  1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].fillna(value = 'unidentified shape',inplace = True)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT                 2803
# unidentified shape    2644
# DISK                  2122
# TRIANGLE              1889
# OTHER                 1402
# CIRCLE                1365
# SPHERE                1054
# FIREBALL              1039
# OVAL                   845
# CIGAR                  617
# FORMATION              434
# VARIOUS                333
# RECTANGLE              303
# CYLINDER               294
# CHEVRON                248
# DIAMOND                234
# EGG                    197
# FLASH                  188
# TEARDROP               119
# CONE                    60
# CROSS                   36
# DELTA                    7
# CRESCENT                 2
# ROUND                    2
# FLARE                    1
# HEXAGON                  1
# DOME                     1
# PYRAMID                  1
# Name: Shape Reported, dtype: int64
